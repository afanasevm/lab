# %% [markdown]
# <a href="https://colab.research.google.com/github/afanasevm/lab/blob/lab/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22lab_work%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа

# %% [markdown]
# Баллы за секции:
# - *Задание 1* - 10 баллов
# - *Задание 2* - 20 баллов
# - *Задание 3* - 30 баллов
# - **Итого** - 60 баллов
#
# Оценка за лабу $ = \frac{score}{6}$

# %% [markdown]
# ## Внимание! Attention! Achtung!

# %% [markdown]
# **Данная лабораторная работа является блокирующей**, т.е. если лабораторная работа не выполнена, то оценка за курс - неуд.
#
# Лабораторная работа считается выполненной, если **за каждое из заданий получено не менее 2 баллов**.

# %% [markdown]
# ## Формат сдачи лабораторной работы

# %% [markdown]
# Данная лабораторная работа сдается так же, как и проект - заполняете данный ноутбук, отправляете его через GitHub с указанием проверяющего.

# %% [markdown]
# **Ассистенты не будут запускать ячейки кода, а смотреть на выведенный результат и код. Если ячейка кода не запущена - балл не ставится, даже при правильно написанном коде.**
#
# ***(Комментарии что курс по Python легче чем по C++ учтены)***

# %% [markdown]
# >**Примечание**
# >
# >Данные задания вдохновлены предметом "Введение в анализ данных" 2 курса, по итогу которого идёт отбор на DS-поток. Если вы видите себя в смежных областях, советуем выполнить данную лабораторку по максимуму.

# %%
# Всё необходимое для выполнения данной лабораторной работы!
import requests
from time import sleep

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Задание 1. Парсинг - 10 баллов

# %% [markdown]
# В этом задании Вам предстоит работать с API сайта <a target="_blank" href="hh.ru">hh.ru</a>. Документация доступна по <a target="_blank" href="https://github.com/hhru/api/blob/master/docs/vacancies.md#search">ссылке</a>.

# %% [markdown]
# <b><font color="red">Внимание!</font> При работе с API не забывайте делать паузы между запросами, иначе вас забанят. Просрочка дедлайна по этой причине не принимается!</b>

# %% [markdown]
# **Задача:**
# 1. выбрать 5 интересующих вас профессий (не смежных, т.е. Аналатик и Data Engineer не считается корректным)
# 2. затем получить доступные по данным профессиям вакансии в Москве и выделить их физические координаты
# 3. нанести полученные координаты на карту местоположения компаний

# %% [markdown]
# *Пример запроса для профессии:*

# %%
URL = 'https://api.hh.ru/vacancies'

params = {
    'text': "Физик-ядерщик",
    'area': 1,
    'page': 0,
    'per_page': 10
}

data = requests.get(URL, params).json()

# %% [markdown]
# Если Ваш запрос прошел успешно, то вы получите следующие ключи (значения данных ключей вы найдете по ссылке на документацию):

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'page', 'per_page', 'clusters', 'arguments', 'fixes', 'suggests', 'alternate_url'])

# %% [markdown]
# >**Примечание**
# >
# >В `data['pages']` будет хранится количество найденных страниц вакансий - для корректного сбора данных Вам нужно пробежать по **КАЖДОЙ** странице и сделать соотвествующие запросы.

# %% [markdown]
# >**Совет**
# >
# >Посмотрите что хранится в `items`!

# %% [markdown]
# (1 балл) Выберете для нас 5 наиболее интересных специальностей и получите по ним имеющиеся вакансии:

# %%
list_of_prof = ['Водитель', 'Повар', 'Психолог', 'Кондуктор', 'Программист']

prof_data = list()
result = 0
URL = 'https://api.hh.ru/vacancies'
for i in list_of_prof:
  params = {
      'text': i,
      'area': 1,
      'page': 0,
      'per_page': 10
  }
  data = requests.get(URL, params).json()
  prof_data.append(data)
  result += data["found"]
prof_data
# Out:
# [{'items': [{'id': '99025528',
#     'premium': False,
#     'name': 'Личный водитель',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': True,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 240000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'anonymous', 'name': 'Анонимная'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T11:34:12+0300',
#     'created_at': '2024-05-15T11:34:12+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99025528',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99025528?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99025528',
#     'relations': [],
#     'employer': {'name': 'Домашний персонал', 'trusted': False},
#     'snippet': {'requirement': '1. Наличие водительских прав категории B. 2. Опыт работы <highlighttext>водителем</highlighttext> не менее 6 лет. 3. Наличие собственного оружия будет преимуществом. ',
#      'responsibility': '1. Перевозка руководителя и членов семьи. 2. Техническое обслуживание и уход за автомобилем. 3. Аккуратное вождение. Соблюдение правил дорожного движения...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99067006',
#     'premium': False,
#     'name': 'Личный водитель',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': True,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 200000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T17:07:54+0300',
#     'created_at': '2024-05-15T17:07:54+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99067006',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99067006?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99067006',
#     'relations': [],
#     'employer': {'id': '3019709',
#      'name': 'Керамакс',
#      'url': 'https://api.hh.ru/employers/3019709',
#      'alternate_url': 'https://hh.ru/employer/3019709',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1129222.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6137477.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6137478.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3019709',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы персональным/личным <highlighttext>водителем</highlighttext> на автомобилях представительского класса от 6 лет. Наличие водительского удостоверения категории В и выше (международные...',
#      'responsibility': 'Своевременная подача автомобиля в указанное место. Обеспечение безопасной и комфортной поездки руководителя и членов семьи (по необходимости) по указанным адресам. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99062555',
#     'premium': False,
#     'name': 'Персональный/семейный водитель',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T16:26:29+0300',
#     'created_at': '2024-05-15T16:26:29+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99062555',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99062555?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99062555',
#     'relations': [],
#     'employer': {'id': '3504682',
#      'name': 'Сарк.Ко Л',
#      'url': 'https://api.hh.ru/employers/3504682',
#      'alternate_url': 'https://hh.ru/employer/3504682',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/2629730.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/2629729.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/547064.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3504682',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы персональным/семейным <highlighttext>водителем</highlighttext> от 6 лет. Хорошее знание Москвы, стаж вождения по Москве от 20 лет. ',
#      'responsibility': None},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99061115',
#     'premium': False,
#     'name': 'Водитель семейный на 5 дней в неделю',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 130000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'деревня Раздоры',
#      'street': 'Рублёво-Успенское шоссе',
#      'building': None,
#      'lat': 55.74486,
#      'lng': 37.301491,
#      'description': None,
#      'raw': 'деревня Раздоры, Рублёво-Успенское шоссе',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15717137'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T16:16:04+0300',
#     'created_at': '2024-05-15T16:16:04+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99061115',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99061115?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99061115',
#     'relations': [],
#     'employer': {'id': '207628',
#      'name': 'ИРМИ',
#      'url': 'https://api.hh.ru/employers/207628',
#      'alternate_url': 'https://hh.ru/employer/207628',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/191197.jpg',
#       '240': 'https://img.hhcdn.ru/employer-logo/1062531.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/1062530.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=207628',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в качестве семейного, персонального <highlighttext>водителя</highlighttext> обязателен. Рекомендации.',
#      'responsibility': 'Вождение автомобиля, сопровождение работодателя и членов семьи ( в том числе, детей) выполнение поручений.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99079766',
#     'premium': False,
#     'name': 'Персональный водитель в семью',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 120000, 'to': 150000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T19:21:12+0300',
#     'created_at': '2024-05-15T19:21:12+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99079766',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99079766?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99079766',
#     'relations': [],
#     'employer': {'id': '692276',
#      'name': 'Амалко',
#      'url': 'https://api.hh.ru/employers/692276',
#      'alternate_url': 'https://hh.ru/employer/692276',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/565288.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/2702621.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/2702622.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=692276',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Требования: опыт работы персональным <highlighttext>водителем</highlighttext>, рекомендации, презентабельный вид (чистый, опрятный) будет проверка службы безопасности.',
#      'responsibility': 'Заказчик работа с руководителем. Задачи Поездки в Москву и МО. Авто: Мерседес. Подготовка автомобиля к работе. Поездки по требованию, поручения. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99041384',
#     'premium': False,
#     'name': 'Персональный водитель вице-президента',
#     'department': {'id': 'etalon-140987-groupmsk',
#      'name': 'ГК «Эталон» Москва'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T13:33:09+0300',
#     'created_at': '2024-05-15T13:33:09+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99041384',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99041384?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99041384',
#     'relations': [],
#     'employer': {'id': '140987',
#      'name': 'Группа компаний Эталон',
#      'url': 'https://api.hh.ru/employers/140987',
#      'alternate_url': 'https://hh.ru/employer/140987',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/5496789.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5496788.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/969193.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=140987',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы персональным <highlighttext>водителем</highlighttext> у первых лиц не менее 5 лет. Отличное знание Москвы и МО. Стаж вождения не менее...',
#      'responsibility': 'Обеспечение высокого уровня профессионального и безопасного вождения автомобиля. Обеспечение профессионального и безопасного вождения. Планирование оптимальных маршрутов. Своевременная подача автомобиля в...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98942751',
#     'premium': False,
#     'name': 'Семейный водитель',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 150000,
#      'to': 180000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-14T15:50:48+0300',
#     'created_at': '2024-05-14T15:50:48+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98942751',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98942751?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98942751',
#     'relations': [],
#     'employer': {'id': '718803',
#      'name': 'Стайнесс',
#      'url': 'https://api.hh.ru/employers/718803',
#      'alternate_url': 'https://hh.ru/employer/718803',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/806856.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/806855.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/147288.gif'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=718803',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Стаж вождения не менее 15 лет. Опыт работы семейным <highlighttext>водителем</highlighttext>. Отличное знание Москвы и МО. Личные качества: чистоплотный, дисциплинированный, соблюдающий...',
#      'responsibility': 'Закупка продуктов, химчистка, выполнение мелких поручений.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'part', 'name': 'Частичная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99049526',
#     'premium': False,
#     'name': 'Персональный водитель руководителя',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 115000, 'to': None, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Пятницкая улица',
#      'building': '50/2с1',
#      'lat': 55.735099,
#      'lng': 37.627112,
#      'description': None,
#      'raw': 'Москва, Пятницкая улица, 50/2с1',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15328590'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T14:41:55+0300',
#     'created_at': '2024-05-15T14:41:55+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99049526',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99049526?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99049526',
#     'relations': [],
#     'employer': {'id': '10369419',
#      'name': 'Союз',
#      'url': 'https://api.hh.ru/employers/10369419',
#      'alternate_url': 'https://hh.ru/employer/10369419',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/6553726.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/6553725.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1233321.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10369419',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Наличие водительских прав категории B. Опыт работы персональным <highlighttext>водителем</highlighttext> на автомобилях представительского класса. Знание города Москвы без использования навигационных средств. ',
#      'responsibility': 'Своевременная подача автомобиля в назначенное время под посадку и высадку руководителя. Доставка руководителя на деловые встречи. Выполнение личных поручений руководителя. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99060768',
#     'premium': False,
#     'name': 'Персональный водитель',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 100000, 'to': 150000, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'переулок Сивцев Вражек',
#      'building': None,
#      'lat': 55.747333,
#      'lng': 37.592563,
#      'description': None,
#      'raw': 'Москва, переулок Сивцев Вражек',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15717012'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T16:13:18+0300',
#     'created_at': '2024-05-15T16:13:18+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99060768',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99060768?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99060768',
#     'relations': [],
#     'employer': {'id': '8883662',
#      'name': 'OWNERO',
#      'url': 'https://api.hh.ru/employers/8883662',
#      'alternate_url': 'https://hh.ru/employer/8883662',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/5483781.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5483780.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/966335.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=8883662',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опытный <highlighttext>водитель</highlighttext> желательно с личным авто. 35-55 лет. Хорошее знание Москвы, особенно ЦАО. Интеллигентное вождение (с контраварийными навыками). ',
#      'responsibility': 'Сопровождение членов семьи (в том числе детей). Своевременная подача авто, планирование и оптимизация маршрутов; проводы и встречи в аэропорту. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99048039',
#     'premium': False,
#     'name': 'Личный водитель в семью',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 120000,
#      'to': 150000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Пятницкая улица',
#      'building': '37',
#      'lat': 55.738591,
#      'lng': 37.628613,
#      'description': None,
#      'raw': 'Москва, Пятницкая улица, 37',
#      'metro': None,
#      'metro_stations': [],
#      'id': '518397'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T14:30:20+0300',
#     'created_at': '2024-05-15T14:30:20+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99048039',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99048039?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99048039',
#     'relations': [],
#     'employer': {'id': '1131846',
#      'name': 'Голд Бизнес',
#      'url': 'https://api.hh.ru/employers/1131846',
#      'alternate_url': 'https://hh.ru/employer/1131846',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/796926.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/796925.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/70559.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1131846',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Наличие водительских прав категории B. -Опыт работы <highlighttext>водителем</highlighttext> не менее 6 лет. -Наличие опыта работы в семьях. -Хорошее знание Москвы...',
#      'responsibility': 'Сопровождение руководителя по служебной и личной необходимости. -Подача авто в нужное время и место, поездки по городу и за его...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '21', 'name': 'Водитель'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   'found': 5882,
#   'pages': 200,
#   'page': 0,
#   'per_page': 10,
#   'clusters': None,
#   'arguments': None,
#   'fixes': None,
#   'suggests': None,
#   'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&items_on_page=10&order_by=publication_time&search_field=name&text=%D0%92%D0%BE%D0%B4%D0%B8%D1%82%D0%B5%D0%BB%D1%8C'},
#  {'items': [{'id': '99051044',
#     'premium': False,
#     'name': 'Повар в семью',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T14:54:33+0300',
#     'created_at': '2024-05-15T14:54:33+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99051044',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99051044?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99051044',
#     'relations': [],
#     'employer': {'id': '12040',
#      'name': 'Европласт, объединение предприятий',
#      'url': 'https://api.hh.ru/employers/12040',
#      'alternate_url': 'https://hh.ru/employer/12040',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/1753927.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/327894.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/1753926.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=12040',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': '<highlighttext>Повар</highlighttext> –универсал в семью. -опыт работы от 3-лет в загородных владениях или в домах VIP - уровня.',
#      'responsibility': 'Приготовление еды для семьи (4 чел) и персонала (4 чел), в день 2-3 приема пищи (Европейкая кухня).'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99083291',
#     'premium': False,
#     'name': 'Шеф-повар в семейный ресторан',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 200000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'проспект Мира',
#      'building': '124к4',
#      'lat': 55.815858,
#      'lng': 37.639563,
#      'description': None,
#      'raw': 'Москва, проспект Мира, 124к4',
#      'metro': {'station_name': 'Алексеевская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.8',
#       'line_id': '6',
#       'lat': 55.807794,
#       'lng': 37.638699},
#      'metro_stations': [{'station_name': 'Алексеевская',
#        'line_name': 'Калужско-Рижская',
#        'station_id': '6.8',
#        'line_id': '6',
#        'lat': 55.807794,
#        'lng': 37.638699},
#       {'station_name': 'ВДНХ',
#        'line_name': 'Калужско-Рижская',
#        'station_id': '6.27',
#        'line_id': '6',
#        'lat': 55.819626,
#        'lng': 37.640751},
#       {'station_name': 'Выставочный центр',
#        'line_name': 'Монорельс',
#        'station_id': '96.553',
#        'line_id': '96',
#        'lat': 55.824086,
#        'lng': 37.638494}],
#      'id': '2838720'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T20:39:24+0300',
#     'created_at': '2024-05-15T20:39:24+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99083291',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99083291?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99083291',
#     'relations': [],
#     'employer': {'id': '4107766',
#      'name': 'МираГриль',
#      'url': 'https://api.hh.ru/employers/4107766',
#      'alternate_url': 'https://hh.ru/employer/4107766',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4107766',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы от 3-ти лет, в том числе и на открытой кухне. Составление калькуляции и ценообразования, порядок составления меню. ',
#      'responsibility': 'Работа с Foodcoast, Laborcoast. Организация и проведение мастер-классов на открытой кухне. Заказ продуктов, контроль качества продуктов, поиск и работа...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99045895',
#     'premium': False,
#     'name': 'Бренд шеф',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 180000,
#      'to': 200000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': None,
#      'street': None,
#      'building': None,
#      'lat': None,
#      'lng': None,
#      'description': None,
#      'raw': None,
#      'metro': {'station_name': 'Пушкинская',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.124',
#       'line_id': '7',
#       'lat': 55.765607,
#       'lng': 37.604356},
#      'metro_stations': [{'station_name': 'Пушкинская',
#        'line_name': 'Таганско-Краснопресненская',
#        'station_id': '7.124',
#        'line_id': '7',
#        'lat': 55.765607,
#        'lng': 37.604356},
#       {'station_name': 'Тверская',
#        'line_name': 'Замоскворецкая',
#        'station_id': '2.122',
#        'line_id': '2',
#        'lat': 55.765343,
#        'lng': 37.603918},
#       {'station_name': 'Чеховская',
#        'line_name': 'Серпуховско-Тимирязевская',
#        'station_id': '9.123',
#        'line_id': '9',
#        'lat': 55.765747,
#        'lng': 37.608493}],
#      'id': '618366'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T14:11:00+0300',
#     'created_at': '2024-05-15T14:11:00+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99045895',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99045895?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99045895',
#     'relations': [],
#     'employer': {'id': '1922458',
#      'name': 'Хлеб и Вино',
#      'url': 'https://api.hh.ru/employers/1922458',
#      'alternate_url': 'https://hh.ru/employer/1922458',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/1695611.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/313311.jpg',
#       '90': 'https://img.hhcdn.ru/employer-logo/1695610.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1922458',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы шеф <highlighttext>поваром</highlighttext>/ бренд шефом не менее 3 лет. Опыт разработки и постановки собственного основного и сезонного меню. ',
#      'responsibility': 'Разработка и внедрение новых рецептур, обеспечение разнообразия меню согласно концепции и ценовой полите двух ресторанов. Контроль себестоимости, товарных запасов, входных...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98930922',
#     'premium': False,
#     'name': 'Шеф-повар',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 400000,
#      'to': 450000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Рочдельская улица',
#      'building': '15с35',
#      'lat': 55.75671,
#      'lng': 37.562542,
#      'description': None,
#      'raw': 'Москва, Рочдельская улица, 15с35',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15704956'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-14T14:15:07+0300',
#     'created_at': '2024-05-14T14:15:07+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98930922',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98930922?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98930922',
#     'relations': [],
#     'employer': {'id': '11058383',
#      'name': 'Щербакова Анна Игоревна',
#      'url': 'https://api.hh.ru/employers/11058383',
#      'alternate_url': 'https://hh.ru/employer/11058383',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11058383',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы на позиции шеф-<highlighttext>повар</highlighttext> от 5 лет. Опыт открытия ресторана с нуля. Знание пекарного дела (ОБЯЗАТЕЛЬНО), без него...',
#      'responsibility': 'Разработка меню и написание технологических карт по заданному ТЗ. Поиск и обучение сотрудников. Составление списка недостающего инвентаря. Контроль и налаживание...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#     'employment': {'id': 'project', 'name': 'Проектная работа'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98979001',
#     'premium': False,
#     'name': 'Су-шеф/шеф-повар',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': True,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 120000,
#      'to': 180000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Киевская улица',
#      'building': '2',
#      'lat': 55.743466,
#      'lng': 37.562721,
#      'description': None,
#      'raw': 'Москва, Киевская улица, 2',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15711140'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T01:04:14+0300',
#     'created_at': '2024-05-15T01:04:14+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98979001',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98979001?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98979001',
#     'relations': [],
#     'employer': {'id': '10351948',
#      'name': 'Innate',
#      'url': 'https://api.hh.ru/employers/10351948',
#      'alternate_url': 'https://hh.ru/employer/10351948',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10351948',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Умение работать по тех картам, приготовление холодных, горячих блюд, закусок. Нетерпимость к грязи и уродству, любовь к чистоте и красоте. ',
#      'responsibility': 'Приготовление блюд. Проработка меню.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': True,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99071995',
#     'premium': False,
#     'name': 'Специалист службы безопасности',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 98000, 'to': None, 'currency': 'RUR', 'gross': True},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Лодочная улица',
#      'building': '27к2',
#      'lat': 55.838501,
#      'lng': 37.462909,
#      'description': None,
#      'raw': 'Москва, Лодочная улица, 27к2',
#      'metro': {'station_name': 'Водный стадион',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.29',
#       'line_id': '2',
#       'lat': 55.838978,
#       'lng': 37.487515},
#      'metro_stations': [{'station_name': 'Водный стадион',
#        'line_name': 'Замоскворецкая',
#        'station_id': '2.29',
#        'line_id': '2',
#        'lat': 55.838978,
#        'lng': 37.487515},
#       {'station_name': 'Сходненская',
#        'line_name': 'Таганско-Краснопресненская',
#        'station_id': '7.138',
#        'line_id': '7',
#        'lat': 55.84926,
#        'lng': 37.44076},
#       {'station_name': 'Тушинская',
#        'line_name': 'Таганско-Краснопресненская',
#        'station_id': '7.145',
#        'line_id': '7',
#        'lat': 55.825479,
#        'lng': 37.437024}],
#      'id': '13979227'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T17:51:37+0300',
#     'created_at': '2024-05-15T17:51:37+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99071995',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99071995?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99071995',
#     'relations': [],
#     'employer': {'id': '5978106',
#      'name': 'МосТАБАК',
#      'url': 'https://api.hh.ru/employers/5978106',
#      'alternate_url': 'https://hh.ru/employer/5978106',
#      'logo_urls': {'240': 'https://img.hhcdn.ru/employer-logo/5543201.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/5543200.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/980593.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5978106',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы в области безопасности - не менее 3 лет. Наличие разрешения и собственного травматического оружия!!! (Кандидаты без лицензии не рассматриваются). ',
#      'responsibility': 'Обеспечение безопасности объекта. Ведение постоянного мониторинга по камерам видеонаблюдения, в целях выявления рисков и предотвращения нанесения ущерба Компании. '},
#     'contacts': None,
#     'schedule': {'id': 'shift', 'name': 'Сменный график'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '120',
#       'name': 'Специалист службы безопасности'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99036423',
#     'premium': False,
#     'name': 'Шеф-повар в ресторан',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 200000,
#      'to': 250000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Пресненская набережная',
#      'building': '12',
#      'lat': 55.749633,
#      'lng': 37.537434,
#      'description': None,
#      'raw': 'Москва, Пресненская набережная, 12',
#      'metro': {'station_name': 'Деловой центр',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.603',
#       'line_id': '97',
#       'lat': 55.7491,
#       'lng': 37.5395},
#      'metro_stations': [{'station_name': 'Деловой центр',
#        'line_name': 'Большая кольцевая линия',
#        'station_id': '97.603',
#        'line_id': '97',
#        'lat': 55.7491,
#        'lng': 37.5395},
#       {'station_name': 'Деловой центр',
#        'line_name': 'Солнцевская',
#        'station_id': '133.468',
#        'line_id': '133',
#        'lat': 55.7491,
#        'lng': 37.5395},
#       {'station_name': 'Москва-Сити',
#        'line_name': 'Филевская',
#        'station_id': '4.179',
#        'line_id': '4',
#        'lat': 55.748056,
#        'lng': 37.532778}],
#      'id': '6963206'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T12:54:24+0300',
#     'created_at': '2024-05-15T12:54:24+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99036423',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99036423?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99036423',
#     'relations': [],
#     'employer': {'id': '5915065',
#      'name': 'Ресторан 360',
#      'url': 'https://api.hh.ru/employers/5915065',
#      'alternate_url': 'https://hh.ru/employer/5915065',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5915065',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Высшее, среднее специальное образование (технология производства продуктов питания / технология общественного питания). Опыт работы Шеф <highlighttext>поваром</highlighttext> от 5-ти лет в...',
#      'responsibility': 'Организация бесперебойной и высококачественной работы кухни ресторана. Контроль Заказа продуктов их качество, мониторинг цен на рынке . Контроль соблюдения требований к...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99012491',
#     'premium': False,
#     'name': 'Шеф-повар',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 150000,
#      'to': 200000,
#      'currency': 'RUR',
#      'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': 'Москва',
#      'street': 'Новинский бульвар',
#      'building': '7',
#      'lat': 55.75167575512146,
#      'lng': 37.58271690062711,
#      'description': None,
#      'raw': 'Москва, Новинский бульвар, 7',
#      'metro': None,
#      'metro_stations': [],
#      'id': '15709506'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T10:01:49+0300',
#     'created_at': '2024-05-15T10:01:49+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99012491',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99012491?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99012491',
#     'relations': [],
#     'employer': {'id': '11063125',
#      'name': 'Туна Бар',
#      'url': 'https://api.hh.ru/employers/11063125',
#      'alternate_url': 'https://hh.ru/employer/11063125',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1275504.JPG',
#       '90': 'https://img.hhcdn.ru/employer-logo/6722318.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6722319.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11063125',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': None,
#      'responsibility': 'Ищем креативного шефа, который сможет поставить кухню, собрать команду, в течение работы генерить какие-то спешелы, новые блюда и тп. '},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '94', 'name': 'Повар, пекарь, кондитер'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98794056',
#     'premium': False,
#     'name': 'Повар',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-13T12:53:03+0300',
#     'created_at': '2024-05-13T12:53:03+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98794056',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98794056?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98794056',
#     'relations': [],
#     'employer': {'id': '2262690',
#      'name': 'ВЕДОМСТВО',
#      'url': 'https://api.hh.ru/employers/2262690',
#      'alternate_url': 'https://hh.ru/employer/2262690',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/3269312.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/3269313.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/707049.jpg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2262690',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Готовность к командировкам на 1 - 1,5 месяца. Уметь готовить домашнюю еду, знание европейской кухни, японской кухни. С опытом работы...',
#      'responsibility': '...двух человек работодателей, персонал не более 10-ти чел. Бывают банкеты- максимум 15 чел. Работа в паре с другим <highlighttext>поваром</highlighttext>.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '40', 'name': 'Другое'}],
#     'accept_incomplete_resumes': True,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98962317',
#     'premium': False,
#     'name': 'Повар в семью',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-14T19:09:43+0300',
#     'created_at': '2024-05-14T19:09:43+0300',
#     'archived': False,
# ...
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98957420',
#     'premium': False,
#     'name': 'Junior Python разработчик',
#     'department': {'id': 'bil-4934-it', 'name': 'билайн: ИТ, Data, Digital'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-14T18:16:13+0300',
#     'created_at': '2024-05-14T18:16:13+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98957420',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98957420?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98957420',
#     'relations': [],
#     'employer': {'id': '4934',
#      'name': 'билайн',
#      'url': 'https://api.hh.ru/employers/4934',
#      'alternate_url': 'https://hh.ru/employer/4934',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/902351.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/4050091.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/4050092.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4934',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Знание Python, Django. Высшее техническое образование. Знания *nix систем, минимум на уровне установки и базовой настройки приложений (nginx/postgres/etc). ',
#      'responsibility': '...миграции, модели, писать SQL запросы. Работать с другими сервисами по API. Взаимодействовать и обмениваться опытом с Frontend <highlighttext>разработчиками</highlighttext> и аналитиками.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99016040',
#     'premium': False,
#     'name': 'Frontend-разработчик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 130000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T10:27:46+0300',
#     'created_at': '2024-05-15T10:27:46+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99016040',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99016040?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99016040',
#     'relations': [],
#     'employer': {'id': '10772647',
#      'name': 'Сайбертех',
#      'url': 'https://api.hh.ru/employers/10772647',
#      'alternate_url': 'https://hh.ru/employer/10772647',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/6545005.jpeg',
#       '240': 'https://img.hhcdn.ru/employer-logo/6545006.jpeg',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/1231141.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10772647',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Опыт работы с React, TypeScript, Redux-Toolkit, styled-components, react-hook-form. Глубокое понимание основных принципов разработки интерфейсов и опыт...',
#      'responsibility': None},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99068368',
#     'premium': False,
#     'name': 'Python-разработчик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 80000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T17:21:39+0300',
#     'created_at': '2024-05-15T17:21:39+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99068368',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99068368?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99068368',
#     'relations': [],
#     'employer': {'id': '1359836',
#      'name': 'МКСКОМ',
#      'url': 'https://api.hh.ru/employers/1359836',
#      'alternate_url': 'https://hh.ru/employer/1359836',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/954502.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/4258541.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/4258540.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1359836',
#      'accredited_it_employer': True,
#      'trusted': True},
#     'snippet': {'requirement': 'Знает основы информатики, модель OSI, что такое булева логика, байт, бит, двоичная система счисления и почему в компьютерах используется именно...',
#      'responsibility': 'Развивать и дорабатывать существующие REST-API сервисы (полу-монолиты) и микросервисы. Разрабатывать новые микросервисы, участвовать в проектировании их архитектуры, помогать...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98109384',
#     'premium': False,
#     'name': 'Программист-разработчик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': {'from': 1000000, 'to': None, 'currency': 'RUR', 'gross': False},
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-04-28T10:26:31+0300',
#     'created_at': '2024-04-28T10:26:31+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98109384',
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98109384?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98109384',
#     'relations': [],
#     'employer': {'id': '11021717',
#      'name': 'Работ',
#      'url': 'https://api.hh.ru/employers/11021717',
#      'alternate_url': 'https://hh.ru/employer/11021717',
#      'logo_urls': None,
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11021717',
#      'accredited_it_employer': False,
#      'trusted': False},
#     'snippet': {'requirement': None, 'responsibility': None},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99056969',
#     'premium': False,
#     'name': 'Frontend Developer (React)',
#     'department': {'id': '12550-12550-pick', 'name': 'ПИК'},
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T15:39:29+0300',
#     'created_at': '2024-05-15T15:39:29+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99056969',
#     'branding': {'type': 'MAKEUP', 'tariff': None},
#     'show_logo_in_search': True,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99056969?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99056969',
#     'relations': [],
#     'employer': {'id': '12550',
#      'name': 'ПИК-специализированный застройщик',
#      'url': 'https://api.hh.ru/employers/12550',
#      'alternate_url': 'https://hh.ru/employer/12550',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/787229.jpg',
#       '240': 'https://img.hhcdn.ru/employer-logo/3589808.jpeg',
#       '90': 'https://img.hhcdn.ru/employer-logo/3589807.jpeg'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=12550',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Отличное знание Javascript. Уверенные знания HTML5, CSS3, опыт кроссбраузерной и мобильной верстки. Опыт работы с Redux, Redux Form. ',
#      'responsibility': 'Разработка на React клиентской части продуктов компании. Автоматизация развертывания и обновления сервисов. Документирование разработанных решений.'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '98933243',
#     'premium': False,
#     'name': 'Junior Frontend разработчик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': None,
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-14T14:35:10+0300',
#     'created_at': '2024-05-14T14:35:10+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=98933243',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/98933243?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/98933243',
#     'relations': [],
#     'employer': {'id': '1429999',
#      'name': 'Циан',
#      'url': 'https://api.hh.ru/employers/1429999',
#      'alternate_url': 'https://hh.ru/employer/1429999',
#      'logo_urls': {'90': 'https://img.hhcdn.ru/employer-logo/3388809.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/3388810.png',
#       'original': 'https://img.hhcdn.ru/employer-logo-original/736958.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1429999',
#      'accredited_it_employer': True,
#      'trusted': True},
#     'snippet': {'requirement': 'Хорошая база по программированию, отличное знание JavaScript. - Желательно: опыт работы с Node.js и React, умение работать с Git. - ',
#      'responsibility': None},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None},
#    {'id': '99068501',
#     'premium': False,
#     'name': 'Frontend разработчик',
#     'department': None,
#     'has_test': False,
#     'response_letter_required': False,
#     'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#     'salary': None,
#     'type': {'id': 'open', 'name': 'Открытая'},
#     'address': {'city': None,
#      'street': None,
#      'building': None,
#      'lat': 55.75576800652564,
#      'lng': 37.61767096817494,
#      'description': None,
#      'raw': 'Аэропорт Домодедово',
#      'metro': None,
#      'metro_stations': [],
#      'id': '230067'},
#     'response_url': None,
#     'sort_point_distance': None,
#     'published_at': '2024-05-15T17:23:16+0300',
#     'created_at': '2024-05-15T17:23:16+0300',
#     'archived': False,
#     'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=99068501',
#     'show_logo_in_search': None,
#     'insider_interview': None,
#     'url': 'https://api.hh.ru/vacancies/99068501?host=hh.ru',
#     'alternate_url': 'https://hh.ru/vacancy/99068501',
#     'relations': [],
#     'employer': {'id': '184015',
#      'name': 'S7 Technics',
#      'url': 'https://api.hh.ru/employers/184015',
#      'alternate_url': 'https://hh.ru/employer/184015',
#      'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/519549.png',
#       '240': 'https://img.hhcdn.ru/employer-logo/2519674.png',
#       '90': 'https://img.hhcdn.ru/employer-logo/2519673.png'},
#      'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=184015',
#      'accredited_it_employer': False,
#      'trusted': True},
#     'snippet': {'requirement': 'Отличное знание JavaScript/ TypeScript. Отличные знания React (классовые компоненты, функциональные компоненты). Понимание принципов и инструментария CI/CD. Желателен опыт работы...',
#      'responsibility': 'Разрабатывать приложение на базе React + next.js. Взаимодействовать с бэкендом на django и fastapi. Разрабатывать базовый функционал и внедрять актуальные...'},
#     'contacts': None,
#     'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#     'working_days': [],
#     'working_time_intervals': [],
#     'working_time_modes': [],
#     'accept_temporary': False,
#     'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#     'accept_incomplete_resumes': False,
#     'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#     'employment': {'id': 'full', 'name': 'Полная занятость'},
#     'adv_response_url': None,
#     'is_adv_vacancy': False,
#     'adv_context': None}],
#   'found': 8650,
#   'pages': 200,
#   'page': 0,
#   'per_page': 10,
#   'clusters': None,
#   'arguments': None,
#   'fixes': None,
#   'suggests': None,
#   'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&items_on_page=10&order_by=publication_time&search_field=name&text=%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82'}]

# %% [markdown]
# (1 балл) Посчитайте сколько всего найдено вакансий:

# %%
result
# Out:
# 26781

# %% [markdown]
# (1 балл) Создайте структуру данных, которая будет хранить в себе имя компании и ее координаты (широта и долгота):

# %%
class Company:
    def __init__(self, name, ln, lg):
      self.name = name
      self.ln = ln
      self.lg = lg

# %% [markdown]
# (1 балл) Создайте экземпляр этой структуры данных для каждой компании, которая выставила вакансию:

# %%
# your code here

# %% [markdown]
# (1 балл) Найдите количество вакансий, у которых заданы координаты (значения данных может быть пустым):

# %%
# your code here

# %% [markdown]
# (1 балл) Отберите вакансии, которые расположены в пределах МКАД (можно грубо):

# %%
# your code here

# %% [markdown]
# (1 балл) Постройте график в координатах "широта-долгота" для отображения вакансий внутри МКАД (не забывайте прописать прозрачность, чтобы увидеть скопления):

# %%
# your code here

# %% [markdown]
# (1 балл) Нанесите все точки вакансий на карту (для этого вам поможет данная <a target="_blank" href="https://plotly.com/python/mapbox-layers/">документации</a>, не забудьте про прозрачность и центрирование по Москве):

# %%
# your code here

# %% [markdown]
# (2 балла) **Сделайте выводы о проделанной работе:**

# %% [markdown]
# >*Подсказки для маленьких: Что вы можете сказать про районы Москвы? Что вы можете сказать про зарплаты? Что вы можете сказать про спрос?*

# %% [markdown]
# Ваши выводы здесь :)

# %% [markdown]
# ## Задание 2. Анализ данных - 20 баллов

# %% [markdown]
# Вам предстоит проанализировать датасет, содержащий информацию об бриллианта, их стоимости и остальных характеристиках.

# %% [markdown]
# Поясним значения хранящиеся в колонках:
# *   `cut` - огранка бриллианта (относится к одной из примерно 10 наиболее распространенных)
# *   `color` - цвет бриллианта, прозрачные бриллианты имеют градацию `D-Z`, "более высокие" буквы - более желтоватые, но часто имеют лучшие значения, поскольку цвет трудно определить один раз в кольце
# *   `clarity` - чистота бриллианта, наличие включений (внутренних дефектов), чем меньше и мельче, тем лучше
# *   `carat_weight` - масса бриллианта (слабо связана с размером бриллианта, т.к. огранка и качество огранки, как правило, играют большую роль)
# *   `cut_quality` - качество ограники по системе оценки GIA Cut
# *   `lab` - лаборатория оценивания
# *   `meas_length` - длина бриллианта
# *   `meas_width` - ширина бриллианта
# *   `meas_depth` - глубина бриллианта
# *   `total_sales_price` - цена бриллианта в долларах.
# *    **и прочие колонки**

# %% [markdown]
# Скачаем данные:

# %%
# !gdown 10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10OJ30qlkE-7zK4JuVTDMY3U4nRB4tu_8
# To: /content/diamonds.csv
# 100% 35.4M/35.4M [00:00<00:00, 49.9MB/s]

# %% [markdown]
# Создадим DataFrame:

# %%
import pandas as pd

diamonds = pd.read_csv("diamonds.csv")
diamonds
# Out:
#         Unnamed: 0       cut    color clarity  carat_weight cut_quality  lab  \
# 0                0     Round        E    VVS2          0.09   Excellent  IGI
# 1                1     Round        E    VVS2          0.09   Very Good  IGI
# 2                2     Round        E    VVS2          0.09   Excellent  IGI
# 3                3     Round        E    VVS2          0.09   Excellent  IGI
# 4                4     Round        E    VVS2          0.09   Very Good  IGI
# ...            ...       ...      ...     ...           ...         ...  ...
# 219698      219699     Round        E     VS1         10.65   Excellent  GIA
# 219699      219700   Radiant  unknown     VS2          5.17     unknown  GIA
# 219700      219701     Round        E     VS1         18.07   Excellent  GIA
# 219701      219702  Princess  unknown     SI2          0.90     unknown  GIA
# 219702      219703      Pear  unknown    VVS2         10.03     unknown  GIA
#
#          symmetry     polish eye_clean  ... meas_depth girdle_min  girdle_max  \
# 0       Very Good  Very Good   unknown  ...       1.79          M           M
# 1       Very Good  Very Good   unknown  ...       1.78        STK         STK
# 2       Very Good  Very Good   unknown  ...       1.77         TN           M
# 3       Very Good  Very Good   unknown  ...       1.78          M         STK
# 4       Very Good  Excellent   unknown  ...       1.82        STK         STK
# ...           ...        ...       ...  ...        ...        ...         ...
# 219698  Excellent  Excellent   unknown  ...       8.66          M         STK
# 219699  Very Good  Very Good   unknown  ...       5.71         TK         XTK
# 219700  Excellent  Excellent   unknown  ...      10.20         TN           M
# 219701       Good       Good   unknown  ...       3.47        XTN         VTK
# 219702  Very Good  Excellent   unknown  ...       7.39    unknown     unknown
#
#         fluor_color  fluor_intensity  fancy_color_dominant_color  \
# 0           unknown              NaN                     unknown
# 1           unknown              NaN                     unknown
# 2           unknown              NaN                     unknown
# 3           unknown              NaN                     unknown
# 4           unknown              NaN                     unknown
# ...             ...              ...                         ...
# 219698      unknown              NaN                     unknown
# 219699      unknown              NaN                       Green
# 219700      unknown              NaN                     unknown
# 219701      unknown            Faint                         Red
# 219702      unknown              NaN                      Yellow
#
#         fancy_color_secondary_color fancy_color_overtone  \
# 0                           unknown              unknown
# 1                           unknown              unknown
# 2                           unknown              unknown
# 3                           unknown              unknown
# 4                           unknown              unknown
# ...                             ...                  ...
# 219698                      unknown              unknown
# 219699                      unknown                  NaN
# 219700                      unknown              unknown
# 219701                      unknown              unknown
# 219702                      unknown              unknown
#
#        fancy_color_intensity total_sales_price
# 0                    unknown               200
# 1                    unknown               200
# 2                    unknown               200
# 3                    unknown               200
# 4                    unknown               200
# ...                      ...               ...
# 219698               unknown           1210692
# 219699           Fancy Light           1292500
# 219700               unknown           1315496
# 219701                 Fancy           1350000
# 219702           Fancy Vivid           1449881
#
# [219703 rows x 26 columns]

# %% [markdown]
# (0.5 балла) Выведете первые 5 строк датасета:

# %%
diamonds.head(5)
# Out:
#    Unnamed: 0    cut color clarity  carat_weight cut_quality  lab   symmetry  \
# 0           0  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 1           1  Round     E    VVS2          0.09   Very Good  IGI  Very Good
# 2           2  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 3           3  Round     E    VVS2          0.09   Excellent  IGI  Very Good
# 4           4  Round     E    VVS2          0.09   Very Good  IGI  Very Good
#
#       polish eye_clean  ... meas_depth girdle_min  girdle_max  fluor_color  \
# 0  Very Good   unknown  ...       1.79          M           M      unknown
# 1  Very Good   unknown  ...       1.78        STK         STK      unknown
# 2  Very Good   unknown  ...       1.77         TN           M      unknown
# 3  Very Good   unknown  ...       1.78          M         STK      unknown
# 4  Excellent   unknown  ...       1.82        STK         STK      unknown
#
#    fluor_intensity  fancy_color_dominant_color  fancy_color_secondary_color  \
# 0              NaN                     unknown                      unknown
# 1              NaN                     unknown                      unknown
# 2              NaN                     unknown                      unknown
# 3              NaN                     unknown                      unknown
# 4              NaN                     unknown                      unknown
#
#   fancy_color_overtone fancy_color_intensity total_sales_price
# 0              unknown               unknown               200
# 1              unknown               unknown               200
# 2              unknown               unknown               200
# 3              unknown               unknown               200
# 4              unknown               unknown               200
#
# [5 rows x 26 columns]

# %% [markdown]
# (0.5 балла) Найдите количество бриллиантов всего в данном датасете:

# %%
len(diamonds)
# Out:
# 219703

# %% [markdown]
# (0.5 балла) Выведите максимальную и минимальную цену бриллианта в формате `номер - цена`:

# %%
min_index, min_price = 0, diamonds["total_sales_price"][0]
max_index, max_price = 0, diamonds["total_sales_price"][0]
for i, row in enumerate(diamonds["total_sales_price"]):
  if row < min_price:
    min_index = i
    min_price = row
  if row > max_price:
    max_index = i
    max_price = row
print(f'{max_index} - {max_price}')
print(f'{min_index} - {min_price}')
# Out:
# 219702 - 1449881
# 0 - 200

# %% [markdown]
# (1 балл) Посчитайте количество пропусков (пропуском считается значение `unknown` или `None`):

# %%
diamonds.isin(['unknown', 'None']).sum().sum()
# Out:
# 1746027

# %% [markdown]
# (1 балл) Найдите в каких столбцах присутствуют пропуски:

# %%
# your code here

# %% [markdown]
# В нашем датасете присутствуют колонки, которые начинаются с `fancy_color_` или `fluor_`. Большинство значений в этих колонках - `unknown` или `None`, поэтому мы считаем их малоинформативными.

# %% [markdown]
# Ваша задача:

# %% [markdown]
# 1. (0.5 балла) найти количество таких колонок, которые начинаются с `fancy_color_` или `fluor_`:

# %%
result = 0
for i in list(diamonds.columns.values):
  if i.startswith("fancy_color_") or i.startswith("fluor_"):
    result += 1
result
# Out:
# 6

# %% [markdown]
# 2. (0.5 балла) найти количество информативных (не `None` или `unknown`) значений в этих колонках:

# %%
# your code here

# %% [markdown]
# 3. (0.5 балла) удалить данные колонки из датасета, сохранив изменения (в дальнейшем работаем измененным датасетом):

# %%
# your code here

# %% [markdown]
# (1 балл) Проделайте тоже самое для колонок, начинающихся с `culet_`:

# %%
# your code here

# %% [markdown]
# (1 балл) Посчитайте сколько бы стоил (в тысячах долларов) сейф, в котором хранились бы все бриллианты из датасета:

# %%
diamonds["total_sales_price"].sum()/1000
# Out:
# 1517721.991

# %% [markdown]
# Немного необоснованных манипуляций.

# %% [markdown]
# (1 балл) Выберите из датасета строки с четными индексами и выведете значения (не меняя нумерацию индексов):

# %%
diamonds[diamonds['Unnamed: 0'] % 2 == 0]
# Out:
#         Unnamed: 0               cut    color clarity  carat_weight  \
# 0                0             Round        E    VVS2          0.09
# 2                2             Round        E    VVS2          0.09
# 4                4             Round        E    VVS2          0.09
# 6                6             Round        E    VVS2          0.09
# 8                8             Round        E    VVS2          0.09
# ...            ...               ...      ...     ...           ...
# 219693      219694             Round        E      IF         12.52
# 219695      219696  Cushion Modified  unknown    VVS1         10.00
# 219697      219698              Oval  unknown     VS1         10.04
# 219699      219700           Radiant  unknown     VS2          5.17
# 219701      219702          Princess  unknown     SI2          0.90
#
#        cut_quality  lab   symmetry     polish eye_clean  ... meas_depth  \
# 0        Excellent  IGI  Very Good  Very Good   unknown  ...       1.79
# 2        Excellent  IGI  Very Good  Very Good   unknown  ...       1.77
# 4        Very Good  IGI  Very Good  Excellent   unknown  ...       1.82
# 6        Very Good  IGI  Very Good  Very Good   unknown  ...       1.84
# 8        Very Good  IGI  Very Good  Very Good   unknown  ...       1.85
# ...            ...  ...        ...        ...       ...  ...        ...
# 219693   Excellent  GIA  Excellent  Excellent   unknown  ...       9.24
# 219695     unknown  GIA  Very Good  Excellent   unknown  ...       8.47
# 219697     unknown  GIA  Excellent  Excellent   unknown  ...       7.90
# 219699     unknown  GIA  Very Good  Very Good   unknown  ...       5.71
# 219701     unknown  GIA       Good       Good   unknown  ...       3.47
#
#        girdle_min  girdle_max  fluor_color  fluor_intensity  \
# 0               M           M      unknown              NaN
# 2              TN           M      unknown              NaN
# 4             STK         STK      unknown              NaN
# 6             STK         STK      unknown              NaN
# 8             STK          TK      unknown              NaN
# ...           ...         ...          ...              ...
# 219693    unknown     unknown      unknown            Faint
# 219695    unknown     unknown      unknown              NaN
# 219697    unknown     unknown      unknown              NaN
# 219699         TK         XTK      unknown              NaN
# 219701        XTN         VTK      unknown            Faint
#
#         fancy_color_dominant_color  fancy_color_secondary_color  \
# 0                          unknown                      unknown
# 2                          unknown                      unknown
# 4                          unknown                      unknown
# 6                          unknown                      unknown
# 8                          unknown                      unknown
# ...                            ...                          ...
# 219693                     unknown                      unknown
# 219695                      Yellow                      unknown
# 219697                      Yellow                      unknown
# 219699                       Green                      unknown
# 219701                         Red                      unknown
#
#        fancy_color_overtone fancy_color_intensity total_sales_price
# 0                   unknown               unknown               200
# 2                   unknown               unknown               200
# 4                   unknown               unknown               200
# 6                   unknown               unknown               200
# 8                   unknown               unknown               200
# ...                     ...                   ...               ...
# 219693              unknown               unknown           1121792
# 219695              unknown           Fancy Vivid           1124122
# 219697              unknown           Fancy Vivid           1161102
# 219699                  NaN           Fancy Light           1292500
# 219701              unknown                 Fancy           1350000
#
# [109852 rows x 26 columns]

# %% [markdown]
# (0.5 балла) А теперь с индексами, кратными 6:

# %%
diamonds[diamonds['Unnamed: 0'] % 6 == 0]
# Out:
#         Unnamed: 0               cut    color clarity  carat_weight  \
# 0                0             Round        E    VVS2          0.09
# 6                6             Round        E    VVS2          0.09
# 12              12             Round        E    VVS2          0.09
# 18              18             Round        E    VVS2          0.09
# 24              24             Round        L      I1          0.34
# ...            ...               ...      ...     ...           ...
# 219677      219678             Round        G     VS1         10.14
# 219683      219684              Pear  unknown     VS2          1.51
# 219689      219690             Round        F      IF         10.66
# 219695      219696  Cushion Modified  unknown    VVS1         10.00
# 219701      219702          Princess  unknown     SI2          0.90
#
#        cut_quality  lab   symmetry     polish eye_clean  ... meas_depth  \
# 0        Excellent  IGI  Very Good  Very Good   unknown  ...       1.79
# 6        Very Good  IGI  Very Good  Very Good   unknown  ...       1.84
# 12       Very Good  IGI  Very Good  Very Good   unknown  ...       1.77
# 18       Excellent  IGI  Very Good  Very Good   unknown  ...       1.78
# 24       Excellent  IGI  Excellent  Excellent   unknown  ...       0.00
# ...            ...  ...        ...        ...       ...  ...        ...
# 219677   Excellent  GIA  Excellent  Excellent   unknown  ...       8.56
# 219683     unknown  GIA  Very Good  Very Good   unknown  ...       3.58
# 219689   Excellent  GIA  Excellent  Excellent   unknown  ...       8.69
# 219695     unknown  GIA  Very Good  Excellent   unknown  ...       8.47
# 219701     unknown  GIA       Good       Good   unknown  ...       3.47
#
#        girdle_min  girdle_max  fluor_color  fluor_intensity  \
# 0               M           M      unknown              NaN
# 6             STK         STK      unknown              NaN
# 12            STK          TK      unknown              NaN
# 18              M           M      unknown              NaN
# 24        unknown     unknown      unknown              NaN
# ...           ...         ...          ...              ...
# 219677          M         STK      unknown              NaN
# 219683    unknown     unknown      unknown            Faint
# 219689          M         STK      unknown              NaN
# 219695    unknown     unknown      unknown              NaN
# 219701        XTN         VTK      unknown            Faint
#
#         fancy_color_dominant_color  fancy_color_secondary_color  \
# 0                          unknown                      unknown
# 6                          unknown                      unknown
# 12                         unknown                      unknown
# 18                         unknown                      unknown
# 24                         unknown                      unknown
# ...                            ...                          ...
# 219677                     unknown                      unknown
# 219683                      Purple                         Pink
# 219689                     unknown                      unknown
# 219695                      Yellow                      unknown
# 219701                         Red                      unknown
#
#        fancy_color_overtone fancy_color_intensity total_sales_price
# 0                   unknown               unknown               200
# 6                   unknown               unknown               200
# 12                  unknown               unknown               200
# 18                  unknown               unknown               200
# 24                  unknown               unknown               204
# ...                     ...                   ...               ...
# 219677              unknown               unknown            851760
# 219683              unknown         Fancy Intense            966401
# 219689              unknown               unknown           1034844
# 219695              unknown           Fancy Vivid           1124122
# 219701              unknown                 Fancy           1350000
#
# [36618 rows x 26 columns]

# %% [markdown]
# (1 балл) Выберете из датасета только категорильные признаки и выведете датасет:

# %%
# your code here

# %% [markdown]
# >**Примечание**
# >
# >Данный датасет можно использовать для задания 3 (с использованием `sklearn`)

# %% [markdown]
# (0.5 балла) Выберете столбец с данными о цене бриллиантов и домножите его на тот столбец, только транспонированный, и выведите полученную матрицу:

# %% [markdown]
# ### Построение графиков

# %% [markdown]
# **Требования к графику:**
#
# 1.   График должен быть подписан
# 2.   Оси должны быть подписаны
# 3.   Должна быть легенда графика
# 4.   График должен быть информативным (желательно без сильных выбросов)
#
# **Все надписи на русском языке!**

# %% [markdown]
# >**Примечание**
# >
# >График необходимо строить для очищенных данных - в них не должно быть пропусков по осям, по которым строите график. При этом **не перезатирайте** имеющийся датафрейм!

# %% [markdown]
# (2 балла) Постройте график `цвет бриллианта - стоимость`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `лабараторная оценка - кол-во бриллиантов`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `вес бриллианта - стоимость`:

# %%
# your code here

# %% [markdown]
# (2 балла) Постройте график `система оценки GIA Cut - кол-во бриллиантов`:

# %%
# your code here

# %% [markdown]
# (2 балла) **Сделайте выводы по построенным графикам:**

# %% [markdown]
# >*Подсказка для маленьких: Что вы можете сказать о графиках полученных выше для данного датасета?*

# %% [markdown]
# Ваши выводы здесь :)

# %% [markdown]
# ## Задание 3. Модель - 30 баллов

# %% [markdown]
# В данном задании вам предстоит построить классифицирующую модель размер алмаза и его стоимости, а затем оценить полученную модель.

# %% [markdown]
# >**Примечание**
# >
# >Данная модель не претендует на самый верный индикатор стоимости алмаза, ведь мы не учитываем ничего больше чем стоимость алмаза. Исключительно для образовательных целей :)

# %% [markdown]
# Для построения модели нам понадобится 4 столбца, а именно:
# - `meas_length`
# - `meas_width`
# - `meas_depth`
# - `total_sales_price`
#
# От остальных столбцов можно избавиться.

# %% [markdown]
# (1 балл) Создайте новый датасет и выведите его первые 10 строк:

# %%
dataset = diamonds[["meas_length", "meas_width", "meas_depth", "total_sales_price"]]
dataset.head(10)
# Out:
#    meas_length  meas_width  meas_depth  total_sales_price
# 0         2.85        2.87        1.79                200
# 1         2.84        2.89        1.78                200
# 2         2.88        2.90        1.77                200
# 3         2.86        2.88        1.78                200
# 4         2.79        2.83        1.82                200
# 5         2.95        2.99        1.81                200
# 6         2.85        2.88        1.84                200
# 7         2.86        2.89        1.78                200
# 8         2.89        2.92        1.85                200
# 9         2.83        2.87        1.80                200

# %% [markdown]
# (1 балл) Перемешайте строки в датафрейме случайным образом:

# %%
dataset = dataset.sample(frac = 1)
dataset.head()
# Out:
#         meas_length  meas_width  meas_depth  total_sales_price
# 3816           4.32        4.34        2.73                556
# 92899          7.06        4.36        2.69               1480
# 13907          4.24        4.28        2.65                672
# 180127         7.30        7.34        4.58               8109
# 106361         4.46        4.05        3.03               1800

# %% [markdown]
# (1 балл) Сформируем новую колонку - для каждого бриллианта найдем сумму Минковского (p=3) по 3 измерениям бриллианта:

# %%
dataset["minkovsky_summ"] = dataset["meas_length"] + dataset["meas_width"] + dataset["meas_depth"]
dataset.head()
# Out:
#         meas_length  meas_width  meas_depth  total_sales_price  minkovsky_summ
# 3816           4.32        4.34        2.73                556           11.39
# 92899          7.06        4.36        2.69               1480           14.11
# 13907          4.24        4.28        2.65                672           11.17
# 180127         7.30        7.34        4.58               8109           19.22
# 106361         4.46        4.05        3.03               1800           11.54

# %% [markdown]
# (1 балл) Сформируем новый датасет из двух колонок - сумма Минковского и `total_sales_price`:

# %%
minkovsky_dataset = dataset[["minkovsky_summ", "total_sales_price"]]
minkovsky_dataset
# Out:
#         minkovsky_summ  total_sales_price
# 3816             11.39                556
# 92899            14.11               1480
# 13907            11.17                672
# 180127           19.22               8109
# 106361           11.54               1800
# ...                ...                ...
# 79798            11.57               1152
# 73468            12.28               1080
# 164481           14.23               4888
# 187521           21.51               9115
# 9025             10.99                622
#
# [219703 rows x 2 columns]

# %% [markdown]
# (1 балл) Разделите вашу выборку на две части в соотношении 8:2 - одна выборка будет для тренировка, а другая для тестов вашей модели:

# %%
from sklearn.model_selection import train_test_split
data = dataset[["meas_length", "meas_width", "meas_depth", "total_sales_price"]]
X_train, X_test, y_train, y_test = train_test_split(data, minkovsky_dataset, test_size=2/8, random_state=4)

# %% [markdown]
# (2 балла) Постройте график зависимости стоимости от вашего нового параметра размера для тренинг-выборки:

# %%
# your code here

# %% [markdown]
# (2 балла) Нанесите на тот же график тестовую выборку, используя другой цвет (не забудьте про параметр прозрачности):

# %%
# your code here

# %% [markdown]
# (3 балла) Найдите для каждой бриллианта из тестовой выборки его "ближайшего соседа" из тренинг-выборки. Для каждого бриллианта из тестовой выборки найдите расстояния до соответствующего ближайшего соседа:

# %%
# your code here

# %% [markdown]
# (3 балла) Найдите насколько сильно (в процентах) отличается цена бриллиантов из тестовой выборки от их соответствующих ближайших соседей:

# %%
# your code here

# %% [markdown]
# **Данная модель является выдумкой автора. Не важен коэффициент ошибки, важны ваши шаги для получения коэффициента.**

# %% [markdown]
# ### Введение в машинное обучение

# %% [markdown]
# Теперь давайте познакомимся с таким сильным инструментом как `sklearn`.

# %% [markdown]
# Вам необходимо:
# 1. выбрать 2 категориальных признака
# 2. на их основе обучить решающее дерево
# 3. оценить среднеквадратичную ошибку цены бриллианта
# 4. сделать пп. 1-3 и выбрать ту пару, которая дает лучший результат
# 5. сделать выводы

# %% [markdown]
# (3 балла) Мы работаем с категориальными признаками, для них не понятно что есть "больше" и "меньше". Поэтому нам нужно предварительно закодировать значения наших признаков, с чем нам поможет [OneHotEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Разбейте датасет на обучающую и тестовую выбору. Для этого вам поможет [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Затем создайте и обучите вашу модель - [DecisionTreeRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html):

# %%
# your code here

# %% [markdown]
# (3 балла) Оцените ошибку вашей модели при помощи [mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html):

# %%
# your code here

# %% [markdown]
# (3 балла) **Сделайте выводы какие категориальные признаки лучше:**

# %% [markdown]
# *Подсказки для маленьких: Что вы можете сказать о зависимости по вашей выборке признаков? Какой вы можете сделать вывод об готовых инструментах для работы и написанных Вами?*

# %% [markdown]
# Ваши выводы здесь :)
